# %% [markdown]
# ## Experiments: Comparing RSAST with other methods

# %%
# Import the os module
import os
import sys
path = '/home/nicolas/mf_rsast/'

try:
    os.chdir(path)
    print("Current working directory: {0}".format(os.getcwd()))
except FileNotFoundError:
    print("Directory: {0} does not exist".format(path))
except NotADirectoryError:
    print("{0} is not a directory".format(path))
except PermissionError:
    print("You do not have permissions to change to {0}".format(path))

sys.path.append('/home/nicolas/mf_rsast/sast')
# Out:
# Directory: /home/nicolas/random_sast/ does not exist

# %%
from sast import *
from sktime.datasets import load_UCR_UEA_dataset, tsc_dataset_names
from sktime.classification.kernel_based import RocketClassifier
import time
import pandas as pd
from sktime.transformations.panel.shapelet_transform import ShapeletTransform
import matplotlib.pyplot as plt
import seaborn as sns
import math
from utils_sast import delete_files_in_directory
from cd_diagram.cd_function import *

# %% [markdown]
# ### Reading Datasets

# %%
# Set directory where the csv files are located
directory = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_by_classifier'

# Create an empty list to store the dataframes
dfs = []

header=['dataset']
res = [str(ele) for ele in range(30)]
header.extend(res)

# Loop through all files in the directory
for filename in os.listdir(directory):
    # Check if the file starts with "df_overall_tunning" and ends with ".csv"
    if filename.endswith(".csv"):
        # Read the csv file into a dataframe
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath, names=header,index_col=False)

        # Append the dataframe to the list
        df['filename']=filename
        dfs.append(df)


# Concatenate all the dataframes in the list into one dataframe
df_other_methods = pd.concat(dfs, ignore_index=True)

#10 Resampling
res=res[:10]

df_other_methods["avg"]=df_other_methods[res].mean(axis=1)

df_other_methods=df_other_methods[['filename','dataset','avg']]
df_other_methods['method']=df_other_methods['filename'].str.split('.').str[0]+"_UCR_10RES"
df_other_methods
df_other_methods=df_other_methods.rename(columns={'avg':'score'})
df_other_methods=df_other_methods[['dataset','score','method']]
# Out:
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)
# /tmp/ipykernel_4877/4288461203.py:17: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filepath, names=header,index_col=False)

# %%
# Set directory where the csv files are located

filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/UCR_ARCHIVE_singleTrainTest_ALL_METHODS_MOD.csv'

df = pd.read_csv(filepath)
df = df.melt(id_vars=["Unnamed: 0"], 
        var_name="method", 
        value_name="score")
df = df.rename(columns={'Unnamed: 0':'dataset'})
df['method'] = df['method']+"_UCR_TRAIN_TEST"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located
#df_other_methods=df_other_methods[df_other_methods.method!="STC"]
filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/SAST_PAPER_singleTrainTest_SAST_ST.csv'
df = pd.read_csv(filepath)
df = df.rename(columns={'folds:':'dataset','STC':'score'})
df['method']="STC_PAPERSAST_TRAIN_TEST"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located

filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/SAST_PAPER_singleTrainTest_SAST_ST.csv'
df = pd.read_csv(filepath)
df = df.rename(columns={'folds:':'dataset','0':'score'})
df['method']="SAST_PAPERSAST_TRAIN_TEST"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located

filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/ROCKET_PAPER_10RESAMPLES_BAKE_OFF.csv'
df = pd.read_csv(filepath)
df = df.melt(id_vars=["Dataset"], 
        var_name="method", 
        value_name="score")
df = df.rename(columns={'Dataset':'dataset'})
df['method'] = df['method']+"_PAPERROCKET_AVG_10RES"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located


filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/ROCKET_PAPER_10RESAMPLES_2018_DS.csv'
df = pd.read_csv(filepath)
df = df.melt(id_vars=["Dataset"], 
        var_name="method", 
        value_name="score")
df = df.rename(columns={'Dataset':'dataset'})
df['method'] = df['method']+"_PAPERROCKET_AVG_10RES"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located


filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/RDST_PAPER_30RESAMPLES_ALL_METHODS.csv'
df = pd.read_csv(filepath)
df = df.melt(id_vars=["dataset_name"], 
        var_name="method", 
        value_name="score")
df = df.rename(columns={'dataset_name':'dataset'})
df['method'] = df['method']+"_PAPERRDST_AVG_30RES"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located

filepath = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/RDST_PAPER_30RESAMPLES_RDST.csv'
df = pd.read_csv(filepath)
df = df.rename(columns={'dataset':'dataset','acc_mean':'score','model':'method'})
df['method'] = df['method']+"_PAPERRDST_AVG_30RES"
df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located
directory = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/Server17_Comparison_Other_Methods_singleTrainTest'

# Create an empty list to store the dataframes
dfs = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    # Check if the file starts with "df_overall_tunning" and ends with ".csv"
    if filename.endswith(".csv"):
        # Read the csv file into a dataframe
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)

        # Append the dataframe to the list
        
        dfs.append(df)

# Concatenate all the dataframes in the list into one dataframe
df = pd.concat(dfs, ignore_index=True)
df=df[['dataset_name','classifier_name','accuracy']]

df=pd.pivot_table(df, index=['dataset_name','classifier_name'],aggfunc='mean').reset_index()
df['method']=df['classifier_name'].str.split('_').str[0]+"_RSAST_TRAIN_TEST"
df=df.rename(columns={'dataset_name':'dataset','accuracy':'score'})

df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the csv files are located
directory = os.getcwd()+'/ExperimentationRSAST/results_other_methods/results_summarized/Server17_Comparison_Other_Methods_Resampling'

# Create an empty list to store the dataframes
dfs = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    # Check if the file starts with "df_overall_tunning" and ends with ".csv"
    if filename.endswith(".csv"):
        # Read the csv file into a dataframe
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)

        # Append the dataframe to the list
        
        dfs.append(df)

# Concatenate all the dataframes in the list into one dataframe
df = pd.concat(dfs, ignore_index=True)
df=df[['dataset_name','classifier_name','accuracy']]

df=pd.pivot_table(df, index=['dataset_name','classifier_name'],aggfunc='mean').reset_index()
df['method']=df['classifier_name'].str.split('_').str[0]+"_RSAST_10RES"
df=df.rename(columns={'dataset_name':'dataset','accuracy':'score'})

df=df[['dataset','score','method']]
df_other_methods=pd.concat([df_other_methods,df])

# %%
# Set directory where the RSAST result csv files are located

directories=[]
default_split_acfandpacf_k_1_10_sast=False
default_split_acfandpacf_k_1_10_notsast=False
default_split_all_k_1_10=False
default_split_all_acfandpacf_k_30_50=False
default_split_maxpacf_none_k_30_50=False
default_split_all_acfandpacf=False
default_split_all_acfandpacf_maxpacf_none_maxacf_k_1_50_p_1_100=False

resampling_acfandpacf_k_1_10_sast=True

if default_split_acfandpacf_k_1_10_sast:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_Comparison_RSAST')
if default_split_acfandpacf_k_1_10_notsast:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_not_used_sast')
if default_split_all_k_1_10:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_Comparison_RSAST_All')   
if default_split_all_acfandpacf_k_30_50:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_Comparison_RSAST_Extra_1')    
if default_split_maxpacf_none_k_30_50:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_Comparison_RSAST_Extra_2')    
if resampling_acfandpacf_k_1_10_sast:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_Resampling_Comparison_RSAST')     
if default_split_all_acfandpacf_maxpacf_none_maxacf_k_1_50_p_1_100:
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server16_Hyperparameter_Tunning')
    directories.append(os.getcwd()+'/ExperimentationRSAST/results_rsast/Server17_Hyperparameter_Tunning')


# Create an empty list to store the dataframes
dfs = []

# Loop through all files in the directory
for directory in directories:
    for filename in os.listdir(directory):
        # Check if the file starts with "df_overall_tunning" and ends with ".csv"
        if filename.startswith("df_all_overall_tunning") and filename.endswith(".csv"):
            # Read the csv file into a dataframe
            filepath = os.path.join(directory, filename)
            df = pd.read_csv(filepath)
            df['rpoint']=df['rpoint'].astype(str)
            df['nb_per_class']=df['nb_per_class'].astype(str)
            df['rpoint']=df['rpoint'].replace("(lenthg ts)//2","half_len")
            df['nb_per_class']=df['nb_per_class'].replace("(max instances per class)//2","half_instance")
            df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
            df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
            df['directory']=directory
            # Append the dataframe to the list
            dfs.append(df)

# Concatenate all the dataframes in the list into one dataframe
df_result = pd.concat(dfs, ignore_index=True)
# df_result.head(3)
# Out:
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# ...
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")
# /tmp/ipykernel_4877/524691405.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(lenthg ts\)//2","half_len")
# /tmp/ipykernel_4877/524691405.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['classifier_name']=df['classifier_name'].str.replace("\(max instances per class\)//2","half_instance")

# %%
hyperparameter='ACF&PACF: n_random_points=10 nb_inst_per_class=10'

# %%
df_result=df_result[['accuracy','dataset_name','classifier_name','time']]
df_result=df_result[df_result["classifier_name"]==hyperparameter]
df_result['classifier_name'].replace(hyperparameter,"RSAST",inplace=True)
hyperparameter="RSAST"
df_result.dataset_name.unique()
# Out:
# array(['GestureMidAirD2', 'ArrowHead', 'UWaveGestureLibraryZ', 'Wafer',
#        'CricketZ', 'FiftyWords', 'FordB', 'MiddlePhalanxOutlineCorrect',
#        'DistalPhalanxOutlineCorrect', 'CricketY', 'PigAirwayPressure',
#        'BirdChicken', 'ACSF1', 'FordA', 'Chinatown', 'SwedishLeaf',
#        'ScreenType', 'EOGHorizontalSignal',
#        'DistalPhalanxOutlineAgeGroup', 'Lightning2', 'Adiac',
#        'MiddlePhalanxOutlineAgeGroup', 'ShapeletSim', 'Strawberry',
#        'GestureMidAirD1', 'Computers', 'SemgHandSubjectCh2', 'TwoLeadECG',
#        'NonInvasiveFetalECGThorax2', 'Haptics', 'CricketX', 'UMD',
#        'DodgerLoopWeekend', 'MixedShapesSmallTrain', 'Fish',
#        'SmallKitchenAppliances', 'LargeKitchenAppliances', 'Car',
#        'RefrigerationDevices', 'ToeSegmentation2', 'SemgHandMovementCh2',
#        'Beef', 'ChlorineConcentration', 'WormsTwoClass',
#        'MixedShapesRegularTrain', 'FreezerSmallTrain', 'DodgerLoopGame',
#        'ShapesAll', 'PigArtPressure', 'ToeSegmentation1', 'Meat',
#        'FreezerRegularTrain', 'BME', 'Yoga', 'MedicalImages',
#        'CinCECGTorso', 'OliveOil', 'Phoneme', 'GunPointMaleVersusFemale',
#        'SonyAIBORobotSurface1', 'MiddlePhalanxTW', 'GesturePebbleZ1',
#        'InsectEPGRegularTrain', 'ECG200', 'PigCVP', 'DistalPhalanxTW',
#        'Symbols', 'Earthquakes', 'UWaveGestureLibraryY',
#        'ProximalPhalanxOutlineAgeGroup', 'Rock', 'TwoPatterns',
#        'EOGVerticalSignal', 'ECGFiveDays', 'FacesUCR', 'GunPoint',
#        'Coffee', 'ProximalPhalanxTW', 'WordSynonyms', 'Ham',
#        'EthanolLevel', 'GesturePebbleZ2', 'Fungi', 'StarLightCurves',
#        'SyntheticControl', 'AllGestureWiimoteX', 'Herring',
#        'NonInvasiveFetalECGThorax1', 'InsectEPGSmallTrain',
#        'GestureMidAirD3', 'AllGestureWiimoteZ', 'UWaveGestureLibraryAll',
#        'GunPointOldVersusYoung', 'PowerCons', 'HouseTwenty',
#        'InlineSkate', 'Plane', 'SonyAIBORobotSurface2', 'Wine', 'FaceAll',
#        'ProximalPhalanxOutlineCorrect', 'Mallat', 'MelbournePedestrian',
#        'InsectWingbeatSound', 'SmoothSubspace', 'PickupGestureWiimoteZ',
#        'ECG5000', 'BeetleFly', 'OSULeaf', 'Lightning7',
#        'DiatomSizeReduction', 'DodgerLoopDay', 'ElectricDevices', 'Trace',
#        'HandOutlines', 'ShakeGestureWiimoteZ', 'SemgHandGenderCh2',
#        'ItalyPowerDemand', 'AllGestureWiimoteY', 'MoteStrain',
#        'UWaveGestureLibraryX', 'FaceFour', 'Crop', 'GunPointAgeSpan',
#        'Worms', 'PLAID', 'PhalangesOutlinesCorrect', 'CBF'], dtype=object)

# %%
len(df_result.dataset_name.unique())
# Out:
# 128

# %%
df_other_methods=df_other_methods.rename(columns={"dataset":"dataset_name","score":"accuracy","method":"classifier_name"})
df_other_methods.classifier_name.unique()
# Out:
# array(['LPS_UCR_10RES', 'RotF_UCR_10RES', 'DTD_C_UCR_10RES',
#        'DDTW_UCR_10RES', 'TSBF_UCR_10RES', 'BoP_UCR_10RES',
#        'EE_UCR_10RES', 'HIVE-COTE_UCR_10RES', 'DTW_F_UCR_10RES',
#        'TWE_UCR_10RES', 'DD_DTW_UCR_10RES', 'TSF_UCR_10RES',
#        'Flat-COTE_UCR_10RES', 'CID_DTW_UCR_10RES', 'MSM_UCR_10RES',
#        'ST_UCR_10RES', 'FS_UCR_10RES', 'LS_UCR_10RES', 'BOSS_UCR_10RES',
#        'SAXVSM_UCR_10RES', 'WDTW_UCR_10RES', 'NB_UCR_TRAIN_TEST',
#        'C45_UCR_TRAIN_TEST', 'SVML_UCR_TRAIN_TEST', 'SVMQ_UCR_TRAIN_TEST',
#        'BN_UCR_TRAIN_TEST', 'RandF_UCR_TRAIN_TEST', 'RotF_UCR_TRAIN_TEST',
#        'MLP_UCR_TRAIN_TEST', 'Euclidean_1NN_UCR_TRAIN_TEST',
#        'DTW_R1_1NN_UCR_TRAIN_TEST', 'DTW_Rn_1NN_UCR_TRAIN_TEST',
#        'DDTW_R1_1NN_UCR_TRAIN_TEST', 'DDTW_Rn_1NN_UCR_TRAIN_TEST',
#        'ERP_1NN_UCR_TRAIN_TEST', 'LCSS_1NN_UCR_TRAIN_TEST',
#        'MSM_1NN_UCR_TRAIN_TEST', 'TWE_1NN_UCR_TRAIN_TEST',
#        'WDDTW_1NN_UCR_TRAIN_TEST', 'WDTW_1NN_UCR_TRAIN_TEST',
#        'DD_DTW_UCR_TRAIN_TEST', 'DTD_C_UCR_TRAIN_TEST',
#        'DTW_F_UCR_TRAIN_TEST', 'ST_UCR_TRAIN_TEST', 'LS_UCR_TRAIN_TEST',
#        'FS_UCR_TRAIN_TEST', 'BoP_UCR_TRAIN_TEST', 'SAXVSM_UCR_TRAIN_TEST',
#        'BOSS_UCR_TRAIN_TEST', 'TSF_UCR_TRAIN_TEST', 'TSBF_UCR_TRAIN_TEST',
#        'LPS_UCR_TRAIN_TEST', 'ACF_UCR_TRAIN_TEST', 'PS_UCR_TRAIN_TEST',
#        'EE_UCR_TRAIN_TEST', 'CID_DTW_UCR_TRAIN_TEST',
#        'Flat-COTE_UCR_TRAIN_TEST', 'HIVE-COTE_UCR_TRAIN_TEST',
#        'STC_PAPERSAST_TRAIN_TEST', 'SAST_PAPERSAST_TRAIN_TEST',
#        'Rocket_PAPERROCKET_AVG_10RES', 'PF_PAPERROCKET_AVG_10RES',
#        'BOSS_PAPERROCKET_AVG_10RES', 'ST_PAPERROCKET_AVG_10RES',
#        'ResNet_PAPERROCKET_AVG_10RES', 'HCTE_PAPERROCKET_AVG_10RES',
#        'ITime_PAPERROCKET_AVG_10RES', 'CHIEF_PAPERROCKET_AVG_10RES',
#        'Arsenal_PAPERRDST_AVG_30RES', 'BOSS_PAPERRDST_AVG_30RES',
#        'CIF_PAPERRDST_AVG_30RES', 'DrCIF_PAPERRDST_AVG_30RES',
#        'HIVE-COTE 2.0_PAPERRDST_AVG_30RES',
#        'HIVE-COTEv1_0_PAPERRDST_AVG_30RES',
#        'InceptionTime_PAPERRDST_AVG_30RES',
#        'MiniRocket_PAPERRDST_AVG_30RES',
#        'ProximityForest_PAPERRDST_AVG_30RES', 'RISE_PAPERRDST_AVG_30RES',
#        'ROCKET_PAPERRDST_AVG_30RES', 'ResNet_PAPERRDST_AVG_30RES',
#        'S-BOSS_PAPERRDST_AVG_30RES', 'STC_PAPERRDST_AVG_30RES',
#        'TDE_PAPERRDST_AVG_30RES', 'TS-CHIEF_PAPERRDST_AVG_30RES',
#        'TSF_PAPERRDST_AVG_30RES', 'WEASEL_PAPERRDST_AVG_30RES',
#        'cBOSS_PAPERRDST_AVG_30RES',
#        'MultiRocket_100k_PAPERRDST_AVG_30RES',
#        'MultiRocket_10k_PAPERRDST_AVG_30RES',
#        'MultiRocket_PAPERRDST_AVG_30RES', 'R_DST_PAPERRDST_AVG_30RES',
#        'R_DST_Ensemble_PAPERRDST_AVG_30RES', 'RDST_RSAST_TRAIN_TEST',
#        'Rocket_RSAST_TRAIN_TEST', 'RDST_RSAST_10RES',
#        'Rocket_RSAST_10RES'], dtype=object)

# %%
#Comparison RSAST, SAST and STC (No resampling)
#df_other_methods=df_other_methods[df_other_methods['classifier_name'].isin(['ST_UCR_TRAIN_TEST','SAST_PAPERSAST_TRAIN_TEST','DTW_R1_1NN_UCR_TRAIN_TEST'])]
#Comparison RSAST and Shapelet Methods (10 resampling)
df_other_methods=df_other_methods[df_other_methods['classifier_name'].isin(['RDST_RSAST_10RES','FS_UCR_10RES', 'LS_UCR_10RES','DTW_R1_1NN_UCR_TRAIN_TEST'])]
#Comparison RSAST and Other Categories (distance, interval, dictionary)(10 resampling)
#df_other_methods=df_other_methods[df_other_methods['classifier_name'].isin(['EE_UCR_10RES', 'TSF_UCR_10RES','TSF_UCR_10RES','BOSS_UCR_10RES','DTW_R1_1NN_UCR_TRAIN_TEST'])]
#Comparison RSAST and SOTA methods(10 resampling)
#df_other_methods=df_other_methods[df_other_methods['classifier_name'].isin(['Rocket_RSAST_10RES','HCTE_PAPERROCKET_AVG_10RES','CHIEF_PAPERROCKET_AVG_10RES','DTW_R1_1NN_UCR_TRAIN_TEST'])]

#df_other_methods=df_other_methods[df_other_methods['classifier_name'].isin(['R_DST_PAPERRDST_AVG_30RES','RDST_RSAST_10RES','Rocket_RSAST_10RES','Rocket_PAPERROCKET_AVG_10RES','HIVE-COTE_UCR_10RES','HCTE_PAPERROCKET_AVG_10RES'])]
df_other_methods['classifier_name'].unique()
# Out:
# array(['FS_UCR_10RES', 'LS_UCR_10RES', 'DTW_R1_1NN_UCR_TRAIN_TEST',
#        'RDST_RSAST_10RES'], dtype=object)

# %%
df_other_methods['classifier_name'].replace("DTW_R1_1NN_UCR_TRAIN_TEST","1NN-DTW",inplace=True)
df_other_methods['classifier_name'].replace("RotF_UCR_TRAIN_TEST","RotF",inplace=True)
df_other_methods['classifier_name'].replace("ST_UCR_TRAIN_TEST","STC",inplace=True)
df_other_methods['classifier_name'].replace("SAST_PAPERSAST_TRAIN_TEST","SAST",inplace=True)
df_other_methods['classifier_name'].replace("FS_UCR_TRAIN_TEST","FS",inplace=True)
df_other_methods['classifier_name'].replace("LS_UCR_TRAIN_TEST","LS",inplace=True)
df_other_methods['classifier_name'].replace("BOSS_UCR_TRAIN_TEST","BOSS",inplace=True)
df_other_methods['classifier_name'].replace("TSBF_UCR_TRAIN_TEST","TSBF",inplace=True)
df_other_methods['classifier_name'].replace("EE_UCR_TRAIN_TEST","EE",inplace=True)
df_other_methods['classifier_name'].replace("HIVE-COTE_UCR_TRAIN_TEST","HIVE-COTE",inplace=True)
df_other_methods['classifier_name'].replace("Rocket_RSAST_TRAIN_TEST","ROCKET",inplace=True)
df_other_methods['classifier_name'].replace("TSBF_UCR_TRAIN_TEST","TSBF",inplace=True)
df_other_methods['classifier_name'].replace("ResNet_PAPERROCKET_AVG_10RES","ResNet",inplace=True)
df_other_methods['classifier_name'].replace("HCTE_PAPERROCKET_AVG_10RES","HIVE-COTE",inplace=True)
df_other_methods['classifier_name'].replace("ITime_PAPERROCKET_AVG_10RES","InceptionTime",inplace=True)
df_other_methods['classifier_name'].replace("CHIEF_PAPERROCKET_AVG_10RES","TS-CHIEF",inplace=True)
df_other_methods['classifier_name'].replace("Rocket_PAPERROCKET_AVG_10RES","ROCKET",inplace=True)
df_other_methods['classifier_name'].replace("BOSS_PAPERROCKET_AVG_10RES","BOSS",inplace=True)
df_other_methods['classifier_name'].replace("ST_PAPERROCKET_AVG_10RES","ST",inplace=True)
df_other_methods['classifier_name'].replace("R_DST_PAPERRDST_AVG_30RES","RDST",inplace=True)
df_other_methods['classifier_name'].replace("FS_UCR_10RES","FS",inplace=True)
df_other_methods['classifier_name'].replace("LS_UCR_10RES","LS",inplace=True)
df_other_methods['classifier_name'].replace("BOSS_UCR_10RES","BOSS",inplace=True)
df_other_methods['classifier_name'].replace("EE_UCR_10RES","EE",inplace=True)
df_other_methods['classifier_name'].replace("TSBF_UCR_10RES","TSBF",inplace=True)
df_other_methods['classifier_name'].replace("RDST_RSAST_10RES","RDST",inplace=True)
df_other_methods['classifier_name'].replace("Rocket_RSAST_10RES","ROCKET",inplace=True)
df_other_methods['classifier_name'].replace("TSF_UCR_10RES","TSF",inplace=True)

# %%
df_other_methods['classifier_name'].unique()
# Out:
# array(['FS', 'LS', '1NN-DTW', 'RDST'], dtype=object)

# %%
# concatenate the two dataframes
concatenated_df = pd.concat([df_other_methods, df_result])

# reset the index of the concatenated dataframe
concatenated_df = concatenated_df.reset_index(drop=True)

# %%
concatenated_df['classifier_name'].unique()
# Out:
# array(['FS', 'LS', '1NN-DTW', 'RDST', 'RSAST'], dtype=object)

# %%
len(concatenated_df.dataset_name.unique())
# Out:
# 128

# %% [markdown]
# ### Overall analysis

# %% [markdown]
# #### Accuracy: RSAST vs Other methods

# %%
max_bx=max(df_result.accuracy)
min_bx=min(df_result.accuracy)



# Plot
fig, ax = plt.subplots()


#order=list(df_to_cd)
sns.boxplot(data=df_result, y='dataset_name', x='accuracy')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')

# Axis details

ax.set(ylabel='dataset name', xlabel='accuracy', title='Accuracy Boxplot for Dataset:'+str(df_result["classifier_name"].unique()[0]))

# save plot
plt.savefig('ExperimentationRSAST/images_boxplot_acc/boxplot_acc_per_ds.png')
# Out:
# /tmp/ipykernel_4877/698087263.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial

# %%
filter_param=concatenated_df#[concatenated_df.classifier_name==hyperparameter]

# %%
stats = filter_param.groupby(['dataset_name','classifier_name'])['accuracy'].agg(['mean', 'count', 'std'])

ci95_hi = []
ci95_lo = []
ci95_hi_lo = []

for i in stats.index:
    m, c, s = stats.loc[i]
    ci95_hi.append(m + 1.96*s/math.sqrt(c))
    ci95_lo.append(m - 1.96*s/math.sqrt(c))
    ci95_hi_lo.append(1.96*s/math.sqrt(c))

#stats['ci95_hi'] = ci95_hi
#stats['ci95_lo'] = ci95_lo
stats['ci95_interval'] = ci95_hi_lo
stats=stats.reset_index()

print(stats[stats['dataset_name']=='Earthquakes'].round(2))
# Out:
#     dataset_name classifier_name  mean  count   std  ci95_interval
# 129  Earthquakes         1NN-DTW  0.72      1   NaN            NaN
# 130  Earthquakes              FS  0.74      1   NaN            NaN
# 131  Earthquakes              LS  0.75      1   NaN            NaN
# 132  Earthquakes            RDST  0.79      1   NaN            NaN
# 133  Earthquakes           RSAST  0.73     10  0.02           0.01

# %%
# create a pivot table with the mean of score by hyperparameter
t_score_by_method=pd.pivot_table(concatenated_df, values='accuracy', columns=['classifier_name'],index=['dataset_name'], aggfunc='mean')
t_score_by_method.iloc[0:25,:]
# Out:
# classifier_name                1NN-DTW        FS        LS      RDST     RSAST
# dataset_name
# ACSF1                              NaN       NaN       NaN  0.768000  0.292000
# Adiac                         0.603581  0.552941  0.439130  0.754987  0.625064
# AllGestureWiimoteX                 NaN       NaN       NaN  0.731714  0.669714
# AllGestureWiimoteY                 NaN       NaN       NaN  0.802857  0.709286
# AllGestureWiimoteZ                 NaN       NaN       NaN  0.680286  0.630857
# ArrowHead                     0.702857  0.657143  0.845143  0.952000  0.780000
# BME                                NaN       NaN       NaN  0.986667  0.952667
# Beef                          0.633333  0.520000  0.750000  0.620000  0.480000
# BeetleFly                     0.700000  0.770000  0.855000  0.900000  0.850000
# BirdChicken                   0.750000  0.820000  0.835000  0.950000  0.815000
# CBF                           0.996667  0.908889  0.970333  0.999111  0.982333
# Car                           0.733333  0.735000  0.851667  0.933333  0.920000
# Chinatown                          NaN       NaN       NaN  0.964431  0.949563
# ChlorineConcentration         0.648438  0.567422  0.588021  0.775651  0.751589
# CinCECGTorso                  0.650725  0.750797  0.855507  0.991087  0.929420
# Coffee                        1.000000  0.921428  0.996429  1.000000  1.000000
# Computers                     0.700000  0.500000  0.648800  0.818400  0.674800
# CricketX                      0.753846  0.487692  0.742051  0.831026  0.818718
# CricketY                      0.743590  0.509744  0.720513  0.854615  0.779744
# CricketZ                      0.753846  0.459231  0.754872  0.849744  0.812308
# Crop                               NaN       NaN       NaN  0.764976  0.624131
# DiatomSizeReduction           0.967320  0.870915  0.939542  0.970588  0.979412
# DistalPhalanxOutlineAgeGroup  0.769784  0.771377  0.803597  0.808633  0.764029
# DistalPhalanxOutlineCorrect   0.717391  0.738849  0.817029  0.822464  0.784783
# DistalPhalanxTW               0.589928  0.617986  0.654676  0.716547  0.742446

# %%
t_score_by_method.iloc[25:49,:]
# Out:
# classifier_name       1NN-DTW        FS        LS      RDST     RSAST
# dataset_name
# DodgerLoopDay             NaN       NaN       NaN  0.542500  0.482500
# DodgerLoopGame            NaN       NaN       NaN  0.859420  0.779710
# DodgerLoopWeekend         NaN       NaN       NaN  0.978261  0.972464
# ECG200               0.770000  0.818000  0.872000  0.879000  0.865000
# ECG5000              0.924444  0.925133  0.938289  0.950133  0.937067
# ECGFiveDays          0.767712  0.991521  0.995122  0.994774  0.985947
# EOGHorizontalSignal       NaN       NaN       NaN  0.782320  0.663260
# EOGVerticalSignal         NaN       NaN       NaN  0.712983  0.679834
# Earthquakes          0.719424  0.736690  0.745324  0.787050  0.731655
# ElectricDevices      0.602127  0.286202  0.762495  0.900752  0.820218
# EthanolLevel              NaN       NaN       NaN  0.752000  0.604800
# FaceAll              0.807692  0.772663  0.903787  0.990947  0.987515
# FaceFour             0.829545  0.847727  0.959091  1.000000  1.000000
# FacesUCR             0.904878  0.689951  0.936390  0.975268  0.953268
# FiftyWords           0.690110  0.514725  0.713626  0.810110  0.720440
# Fish                 0.822857  0.764000  0.935429  0.988000  0.965143
# FordA                0.554545  0.775758  0.915985  0.941364  0.847045
# FordB                0.619753  0.779012  0.897654  0.921975  0.838765
# FreezerRegularTrain       NaN       NaN       NaN  0.996596  0.970316
# FreezerSmallTrain         NaN       NaN       NaN  0.995474  0.847789
# Fungi                     NaN       NaN       NaN  0.634409  0.591398
# GestureMidAirD1           NaN       NaN       NaN  0.738462  0.646154
# GestureMidAirD2           NaN       NaN       NaN  0.569231  0.530769
# GestureMidAirD3           NaN       NaN       NaN  0.353077  0.353846

# %%
t_score_by_method.iloc[49:75,:]
# Out:
# classifier_name                1NN-DTW        FS        LS      RDST     RSAST
# dataset_name
# GesturePebbleZ1                    NaN       NaN       NaN  0.984884  0.934302
# GesturePebbleZ2                    NaN       NaN       NaN  0.974684  0.937342
# GunPoint                      0.906667  0.931334  0.986000  0.993333  0.979333
# GunPointAgeSpan                    NaN       NaN       NaN  0.993354  0.969937
# GunPointMaleVersusFemale           NaN       NaN       NaN  0.997152  0.989241
# GunPointOldVersusYoung             NaN       NaN       NaN  1.000000  0.971746
# Ham                           0.466667  0.664762  0.812381  0.854286  0.808571
# HandOutlines                  0.881081  0.827027  0.820270  0.943514  0.845135
# Haptics                       0.376623  0.370130  0.458117  0.626623  0.488312
# Herring                       0.531250  0.576562  0.621875  0.607812  0.593750
# HouseTwenty                        NaN       NaN       NaN  0.917647  0.827731
# InlineSkate                   0.383636  0.264000  0.368727  0.398909  0.334364
# InsectEPGRegularTrain              NaN       NaN       NaN  1.000000  0.910442
# InsectEPGSmallTrain                NaN       NaN       NaN  0.986747  0.687952
# InsectWingbeatSound           0.355051  0.487526  0.591818  0.645657  0.549444
# ItalyPowerDemand              0.950437  0.913703  0.955005  0.952867  0.963265
# LargeKitchenAppliances        0.794667  0.440800  0.752800  0.913067  0.741333
# Lightning2                    0.868852  0.540983  0.759016  0.700000  0.749180
# Lightning7                    0.726027  0.150685  0.750685  0.697260  0.746575
# Mallat                        0.933902  0.896077  0.947122  0.947420  0.910576
# Meat                          0.933333  0.898333  0.816667  1.000000  0.990000
# MedicalImages                 0.736842  0.623026  0.703947  0.800526  0.649211
# MelbournePedestrian                NaN       NaN       NaN  0.955966  0.865929
# MiddlePhalanxOutlineAgeGroup  0.500000  0.723368  0.675974  0.795455  0.709740
# MiddlePhalanxOutlineCorrect   0.697595  0.603247  0.817869  0.842268  0.810653
# MiddlePhalanxTW               0.506494  0.538312  0.553896  0.624675  0.535714

# %%
t_score_by_method.iloc[40:100,:]
# Out:
# classifier_name                  1NN-DTW        FS        LS      RDST  \
# dataset_name
# Fish                            0.822857  0.764000  0.935429  0.988000
# FordA                           0.554545  0.775758  0.915985  0.941364
# FordB                           0.619753  0.779012  0.897654  0.921975
# FreezerRegularTrain                  NaN       NaN       NaN  0.996596
# FreezerSmallTrain                    NaN       NaN       NaN  0.995474
# Fungi                                NaN       NaN       NaN  0.634409
# GestureMidAirD1                      NaN       NaN       NaN  0.738462
# GestureMidAirD2                      NaN       NaN       NaN  0.569231
# GestureMidAirD3                      NaN       NaN       NaN  0.353077
# GesturePebbleZ1                      NaN       NaN       NaN  0.984884
# GesturePebbleZ2                      NaN       NaN       NaN  0.974684
# GunPoint                        0.906667  0.931334  0.986000  0.993333
# GunPointAgeSpan                      NaN       NaN       NaN  0.993354
# GunPointMaleVersusFemale             NaN       NaN       NaN  0.997152
# GunPointOldVersusYoung               NaN       NaN       NaN  1.000000
# Ham                             0.466667  0.664762  0.812381  0.854286
# HandOutlines                    0.881081  0.827027  0.820270  0.943514
# Haptics                         0.376623  0.370130  0.458117  0.626623
# Herring                         0.531250  0.576562  0.621875  0.607812
# HouseTwenty                          NaN       NaN       NaN  0.917647
# InlineSkate                     0.383636  0.264000  0.368727  0.398909
# InsectEPGRegularTrain                NaN       NaN       NaN  1.000000
# InsectEPGSmallTrain                  NaN       NaN       NaN  0.986747
# InsectWingbeatSound             0.355051  0.487526  0.591818  0.645657
# ItalyPowerDemand                0.950437  0.913703  0.955005  0.952867
# LargeKitchenAppliances          0.794667  0.440800  0.752800  0.913067
# Lightning2                      0.868852  0.540983  0.759016  0.700000
# Lightning7                      0.726027  0.150685  0.750685  0.697260
# Mallat                          0.933902  0.896077  0.947122  0.947420
# Meat                            0.933333  0.898333  0.816667  1.000000
# MedicalImages                   0.736842  0.623026  0.703947  0.800526
# MelbournePedestrian                  NaN       NaN       NaN  0.955966
# MiddlePhalanxOutlineAgeGroup    0.500000  0.723368  0.675974  0.795455
# MiddlePhalanxOutlineCorrect     0.697595  0.603247  0.817869  0.842268
# MiddlePhalanxTW                 0.506494  0.538312  0.553896  0.624675
# MixedShapesRegularTrain              NaN       NaN       NaN  0.976660
# MixedShapesSmallTrain                NaN       NaN       NaN  0.952165
# MoteStrain                      0.834665  0.791853  0.880591  0.946326
# NonInvasiveFetalECGThorax1      0.790331  0.704122  0.645089  0.930229
# NonInvasiveFetalECGThorax2      0.864631  0.756285  0.714962  0.938677
# OSULeaf                         0.590909  0.678512  0.772727  0.975207
# OliveOil                        0.833333  0.743333  0.166667  0.900000
# PLAID                                NaN       NaN       NaN  0.905400
# PhalangesOutlinesCorrect        0.728438  0.730187  0.780303  0.850117
# Phoneme                         0.228376  0.167985  0.151582  0.319673
# PickupGestureWiimoteZ                NaN       NaN       NaN  0.778000
# PigAirwayPressure                    NaN       NaN       NaN  0.535096
# PigArtPressure                       NaN       NaN       NaN  0.802404
# PigCVP                               NaN       NaN       NaN  0.703365
# Plane                           1.000000  0.974286  0.994286  1.000000
# PowerCons                            NaN       NaN       NaN  0.983333
# ProximalPhalanxOutlineAgeGroup  0.804878  0.782818  0.818537  0.882927
# ProximalPhalanxOutlineCorrect   0.783505  0.782439  0.805155  0.884192
# ProximalPhalanxTW               0.760976  0.716097  0.787805  0.826829
# RefrigerationDevices            0.464000  0.536800  0.628267  0.776800
# Rock                                 NaN       NaN       NaN  0.624000
# ScreenType                      0.397333  0.380000  0.442667  0.655733
# SemgHandGenderCh2                    NaN       NaN       NaN  0.932333
# SemgHandMovementCh2                  NaN       NaN       NaN  0.715778
# SemgHandSubjectCh2                   NaN       NaN       NaN  0.888000
#
# classifier_name                    RSAST
# dataset_name
# Fish                            0.965143
# FordA                           0.847045
# FordB                           0.838765
# FreezerRegularTrain             0.970316
# FreezerSmallTrain               0.847789
# Fungi                           0.591398
# GestureMidAirD1                 0.646154
# GestureMidAirD2                 0.530769
# GestureMidAirD3                 0.353846
# GesturePebbleZ1                 0.934302
# GesturePebbleZ2                 0.937342
# GunPoint                        0.979333
# GunPointAgeSpan                 0.969937
# GunPointMaleVersusFemale        0.989241
# GunPointOldVersusYoung          0.971746
# Ham                             0.808571
# HandOutlines                    0.845135
# Haptics                         0.488312
# Herring                         0.593750
# HouseTwenty                     0.827731
# InlineSkate                     0.334364
# InsectEPGRegularTrain           0.910442
# InsectEPGSmallTrain             0.687952
# InsectWingbeatSound             0.549444
# ItalyPowerDemand                0.963265
# LargeKitchenAppliances          0.741333
# Lightning2                      0.749180
# Lightning7                      0.746575
# Mallat                          0.910576
# Meat                            0.990000
# MedicalImages                   0.649211
# MelbournePedestrian             0.865929
# MiddlePhalanxOutlineAgeGroup    0.709740
# MiddlePhalanxOutlineCorrect     0.810653
# MiddlePhalanxTW                 0.535714
# MixedShapesRegularTrain         0.909320
# MixedShapesSmallTrain           0.801196
# MoteStrain                      0.832748
# NonInvasiveFetalECGThorax1      0.899746
# NonInvasiveFetalECGThorax2      0.933333
# OSULeaf                         0.715289
# OliveOil                        0.870000
# PLAID                           0.805214
# PhalangesOutlinesCorrect        0.799417
# Phoneme                         0.229852
# PickupGestureWiimoteZ           0.708000
# PigAirwayPressure               0.298558
# PigArtPressure                  0.607212
# PigCVP                          0.610577
# Plane                           1.000000
# PowerCons                       0.866111
# ProximalPhalanxOutlineAgeGroup  0.833171
# ProximalPhalanxOutlineCorrect   0.855670
# ProximalPhalanxTW               0.812683
# RefrigerationDevices            0.623200
# Rock                            0.762000
# ScreenType                      0.449867
# SemgHandGenderCh2               0.896167
# SemgHandMovementCh2             0.616000
# SemgHandSubjectCh2              0.920889

# %%
t_score_by_method.iloc[99:128,:]
# Out:
# classifier_name          1NN-DTW        FS        LS      RDST     RSAST
# dataset_name
# SemgHandSubjectCh2           NaN       NaN       NaN  0.888000  0.920889
# ShakeGestureWiimoteZ         NaN       NaN       NaN  0.960000  0.796000
# ShapeletSim             0.650000  1.000000  0.933889  0.998889  0.477778
# ShapesAll               0.768333  0.593333  0.762500  0.942000  0.741333
# SmallKitchenAppliances  0.642667  0.333333  0.658400  0.834667  0.732267
# SmoothSubspace               NaN       NaN       NaN  0.998667  0.862000
# SonyAIBORobotSurface1   0.725458  0.904493  0.898669  0.893511  0.952413
# SonyAIBORobotSurface2   0.831060  0.858867  0.909444  0.925498  0.905771
# StarLightCurves         0.906629  0.911085  0.942035  0.979917  0.960648
# Strawberry              0.940541  0.914054  0.924865  0.985676  0.947568
# SwedishLeaf             0.792000  0.764160  0.899840  0.967840  0.874080
# Symbols                 0.949749  0.913166  0.913367  0.941407  0.783819
# SyntheticControl        0.993333  0.920333  0.994000  0.992667  0.957333
# ToeSegmentation1        0.771930  0.918860  0.935965  0.942105  0.941667
# ToeSegmentation2        0.838462  0.845385  0.923846  0.968462  0.930769
# Trace                   1.000000  1.000000  0.998000  1.000000  0.999000
# TwoLeadECG              0.905180  0.946883  0.985953  0.996576  0.981212
# TwoPatterns             1.000000  0.692450  0.994225  1.000000  0.991775
# UMD                          NaN       NaN       NaN  1.000000  0.912500
# UWaveGestureLibraryAll  0.891681  0.631686  0.906421  0.979146  0.969821
# UWaveGestureLibraryX    0.727527  0.658068  0.803210  0.851535  0.686991
# UWaveGestureLibraryY    0.634003  0.700251  0.716723  0.778224  0.557259
# UWaveGestureLibraryZ    0.658291  0.580905  0.733585  0.777024  0.609296
# Wafer                   0.979883  0.976768  0.996025  1.000000  1.000000
# Wine                    0.574074  0.788889  0.529630  0.981481  0.909259
# WordSynonyms            0.648903  0.469749  0.571473  0.756740  0.680721
# Worms                   0.584416  0.610390  0.631169  0.687013  0.627273
# WormsTwoClass           0.623377  0.700000  0.742857  0.705195  0.701299
# Yoga                    0.836667  0.719134  0.827500  0.924500  0.842867

# %%
t_score_by_method.to_csv("ExperimentationRSAST/results_comparison_rsast.csv")

# %%
t_score_by_method.describe().round(2)
# Out:
# classifier_name  1NN-DTW     FS     LS    RDST   RSAST
# count              85.00  85.00  85.00  128.00  128.00
# mean                0.74   0.70   0.79    0.86    0.79
# std                 0.17   0.20   0.18    0.15    0.17
# min                 0.23   0.15   0.15    0.32    0.23
# 25%                 0.64   0.58   0.71    0.78    0.68
# 50%                 0.75   0.73   0.82    0.91    0.81
# 75%                 0.86   0.85   0.92    0.98    0.93
# max                 1.00   1.00   1.00    1.00    1.00

# %%
t_score_by_method=pd.pivot_table(concatenated_df, values='accuracy', index=['classifier_name'],columns=['dataset_name'], aggfunc='mean')
t_score_by_method=t_score_by_method.transpose()#[[hyperparameter,"SAST"]].round(2)

# %%
pd.pivot_table(concatenated_df, values='accuracy', index=['classifier_name'], aggfunc='var').round(4)
# Out:
#                  accuracy
# classifier_name
# 1NN-DTW            0.0284
# FS                 0.0380
# LS                 0.0311
# RDST               0.0213
# RSAST              0.0302

# %%
pv_all=pd.pivot_table(df_result,index=['dataset_name'],values='accuracy',aggfunc="count")
ds_complete=pv_all[pv_all.accuracy==max(pv_all.accuracy)].reset_index().dataset_name.unique()
df_result=df_result[df_result.dataset_name.isin(ds_complete)]

df_other_methods=df_other_methods[df_other_methods.dataset_name.isin(ds_complete)]

pv_all=pd.pivot_table(df_other_methods,index=['dataset_name'],values='accuracy',aggfunc="count")
ds_complete=pv_all[pv_all.accuracy==max(pv_all.accuracy)].reset_index().dataset_name.unique()
df_other_methods=df_other_methods[df_other_methods.dataset_name.isin(ds_complete)]

df_result=df_result[df_result.dataset_name.isin(ds_complete)]
# concatenate the two dataframes
concatenated_df = pd.concat([df_other_methods, df_result])

# reset the index of the concatenated dataframe
concatenated_df = concatenated_df.reset_index(drop=True)

# %%
#concatenated_df=concatenated_df[concatenated_df.dataset_name!="Fungi"]
df_perf=pd.pivot_table(concatenated_df, values='accuracy', index=['classifier_name','dataset_name'], aggfunc='mean')

# %%
df_perf=df_perf.reset_index()
pd.pivot_table(df_perf, values='accuracy', index=['classifier_name'], aggfunc='count')
# Out:
#                  accuracy
# classifier_name
# 1NN-DTW                85
# FS                     85
# LS                     85
# RDST                   85
# RSAST                  85

# %%
#concatenated_df['classifier_name']=concatenated_df['classifier_name'].str.split('_').str[0]
score_by_method=pd.pivot_table(df_perf, values='accuracy', columns=['classifier_name'],index=['dataset_name'], aggfunc='mean')
score_by_method
# Out:
# classifier_name   1NN-DTW        FS        LS      RDST     RSAST
# dataset_name
# Adiac            0.603581  0.552941  0.439130  0.754987  0.625064
# ArrowHead        0.702857  0.657143  0.845143  0.952000  0.780000
# Beef             0.633333  0.520000  0.750000  0.620000  0.480000
# BeetleFly        0.700000  0.770000  0.855000  0.900000  0.850000
# BirdChicken      0.750000  0.820000  0.835000  0.950000  0.815000
# ...                   ...       ...       ...       ...       ...
# Wine             0.574074  0.788889  0.529630  0.981481  0.909259
# WordSynonyms     0.648903  0.469749  0.571473  0.756740  0.680721
# Worms            0.584416  0.610390  0.631169  0.687013  0.627273
# WormsTwoClass    0.623377  0.700000  0.742857  0.705195  0.701299
# Yoga             0.836667  0.719134  0.827500  0.924500  0.842867
#
# [85 rows x 5 columns]

# %%
#hyperparameter='RDST_30RES'

# %%
t_score_by_method=pd.pivot_table(df_perf, values='accuracy', index=['classifier_name'],columns=['dataset_name'], aggfunc='mean')
t_score_by_method=t_score_by_method.transpose()#[[hyperparameter,"SAST"]].round(2)
for methods in t_score_by_method.columns.drop(hyperparameter):
    print("method: "+methods+" vs "+hyperparameter)
    total_wins=len(t_score_by_method[0<(t_score_by_method[hyperparameter].round(2)-t_score_by_method[methods].round(2))])
    print("winning "+hyperparameter+": "+str(total_wins))
    total_loss=len(t_score_by_method[0>(t_score_by_method[hyperparameter].round(2)-t_score_by_method[methods].round(2))])
    print("losse "+hyperparameter+": "+str(total_loss))
    total_draws=len(t_score_by_method[0==(t_score_by_method[hyperparameter].round(2)-t_score_by_method[methods].round(2))])
    print("draws: "+str(total_draws))
# Out:
# method: 1NN-DTW vs RSAST
# winning RSAST: 61
# losse RSAST: 18
# draws: 6
# method: FS vs RSAST
# winning RSAST: 73
# losse RSAST: 7
# draws: 5
# method: LS vs RSAST
# winning RSAST: 40
# losse RSAST: 34
# draws: 11
# method: RDST vs RSAST
# winning RSAST: 6
# losse RSAST: 71
# draws: 8

# %%
for methods in t_score_by_method.columns.drop(hyperparameter):
    print("method: "+methods+" vs "+hyperparameter)
    win_ds=t_score_by_method[0.4<(t_score_by_method[hyperparameter].round(2)-t_score_by_method[methods].round(2))]
    total_wins=len(win_ds)
    print("winning "+hyperparameter+": "+str(total_wins))
    print(win_ds)
    loss_ds=t_score_by_method[-0.4>(t_score_by_method[hyperparameter].round(2)-t_score_by_method[methods].round(2))]
    total_loss=len(loss_ds)
    print("losse "+hyperparameter+": "+str(total_loss))
    print(loss_ds)
    print("--------------------------------------")
# Out:
# method: 1NN-DTW vs RSAST
# winning RSAST: 0
# Empty DataFrame
# Columns: [1NN-DTW, FS, LS, RDST, RSAST]
# Index: []
# losse RSAST: 0
# Empty DataFrame
# Columns: [1NN-DTW, FS, LS, RDST, RSAST]
# Index: []
# --------------------------------------
# method: FS vs RSAST
# winning RSAST: 2
# classifier_name   1NN-DTW        FS        LS      RDST     RSAST
# dataset_name
# ElectricDevices  0.602127  0.286202  0.762495  0.900752  0.820218
# Lightning7       0.726027  0.150685  0.750685  0.697260  0.746575
# losse RSAST: 1
# classifier_name  1NN-DTW   FS        LS      RDST     RSAST
# dataset_name
# ShapeletSim         0.65  1.0  0.933889  0.998889  0.477778
# --------------------------------------
# method: LS vs RSAST
# winning RSAST: 1
# classifier_name   1NN-DTW        FS        LS  RDST  RSAST
# dataset_name
# OliveOil         0.833333  0.743333  0.166667   0.9   0.87
# losse RSAST: 1
# classifier_name  1NN-DTW   FS        LS      RDST     RSAST
# dataset_name
# ShapeletSim         0.65  1.0  0.933889  0.998889  0.477778
# --------------------------------------
# method: RDST vs RSAST
# winning RSAST: 0
# Empty DataFrame
# Columns: [1NN-DTW, FS, LS, RDST, RSAST]
# Index: []
# losse RSAST: 1
# classifier_name  1NN-DTW   FS        LS      RDST     RSAST
# dataset_name
# ShapeletSim         0.65  1.0  0.933889  0.998889  0.477778
# --------------------------------------

# %%
custom_style = {
    'axes.labelcolor': 'black',
    'axes.edgecolor': 'white',
    'axes.facecolor': 'lightgrey',
    'axes.grid': True,
    'grid.color': 'white'
    # Add more style configurations as needed
}
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#delete_files_in_directory("ExperimentationRSAST/images_one_vs_one_comparison/")
for method in score_by_method.columns.drop(hyperparameter):
    y=score_by_method[hyperparameter]
    x=score_by_method[method]

    # set the style of the plot
    #plt.style.use('seaborn')
    plt.style.use(custom_style)

    # create the plot
    fig, ax = plt.subplots(figsize=(8, 6))

    # plot the line
    ax.plot([0,1], [0,1])

    # plot the points
    ax.scatter(x, y, color='blue', edgecolor='blue', s=30, zorder=10)

    # add labels and title
    ax.set_ylabel(hyperparameter)
    ax.set_xlabel(method)
    ax.set_title('Accuracy')
    plt.tight_layout()
    
    
    plt.savefig('ExperimentationRSAST/images_one_vs_one_comparison/'+hyperparameter+'vs'+method+'.png')
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial

# %%
# create a pivot table with the mean of time by hyperparameter
time_per_method=pd.pivot_table(df_result, values='time', columns=['classifier_name'],index=['dataset_name'], aggfunc='mean')/60
time_per_method
# Out:
# classifier_name      RSAST
# dataset_name
# Adiac             0.404516
# ArrowHead         0.074400
# Beef              0.442508
# BeetleFly         0.446825
# BirdChicken       0.397464
# ...                    ...
# Wine              0.049412
# WordSynonyms      0.624260
# Worms            15.356934
# WormsTwoClass     4.971590
# Yoga              0.250619
#
# [85 rows x 1 columns]

# %% [markdown]
# #### Generate CD Diagram comparison

# %%
concatenated_df.classifier_name.unique()
# Out:
# array(['FS', 'LS', '1NN-DTW', 'RDST', 'RSAST'], dtype=object)

# %%
df_perf=pd.pivot_table(concatenated_df, values='accuracy', index=['classifier_name','dataset_name'], aggfunc='mean')
df_perf=df_perf.reset_index()
draw_cd_diagram(df_perf, labels=True, fname='ExperimentationRSAST/images_cd_diagram/cd-diagram_overall_comparison_other_method.png')
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# {0: 'FS', 1: '1NN-DTW', 2: 'LS', 3: 'RSAST', 4: 'RDST'}
# [2, 3]

# %%
df_perf["classifier_name"].unique()
# Out:
# array(['1NN-DTW', 'FS', 'LS', 'RDST', 'RSAST'], dtype=object)

# %%
_, average_ranks, _ = wilcoxon_holm(df_perf=df_perf)
min_rank= min(average_ranks)
average_ranks=pd.DataFrame(average_ranks)
average_ranks
# Out:
#                 0
# FS       4.294118
# 1NN-DTW  3.758824
# LS       2.882353
# RSAST    2.752941
# RDST     1.311765

# %%
uca_ds=pd.read_excel("ExperimentationRSAST/DataSetsUCLASummary.xlsx")

uca_ds.columns
# Out:
# Index(['USED SAST', 'BAKE OFF', 'N RUNS S17_S16_HT', 'N RUNS S17_SAST_DS',
#        'N RUNS S17_SAST_DS_all', 'N RUNS S17_SAST_DS_extra_1',
#        'N RUNS S17_SAST_DS_extra_2', 'N RUNS S17_OTHER_DEFAULT_SPLIT',
#        'N RUNS S17_RSAST_R10', 'N RUNS S17_OTHER_R10', 'ID', 'Name', 'Type',
#        'Train ', 'Test ', 'Class', 'Length', 'RSAST (10,10) WORST SAST?',
#        'O(|c|nm²)', 'O(|c|nm³)', 'Approx Time (hours)', 'L25', 'L50', 'L75',
#        'ED (w=0)', 'DTW (learned_w) ', 'DTW (w=100)', 'Default rate',
#        'Data donor/editor', '50/L', 'Unnamed: 30'],
#       dtype='object')

# %%
concatenated_df=concatenated_df.merge(uca_ds, left_on=['dataset_name'],right_on=['Name'])
concatenated_df.columns
# Out:
# Index(['dataset_name', 'accuracy', 'classifier_name', 'time', 'USED SAST',
#        'BAKE OFF', 'N RUNS S17_S16_HT', 'N RUNS S17_SAST_DS',
#        'N RUNS S17_SAST_DS_all', 'N RUNS S17_SAST_DS_extra_1',
#        'N RUNS S17_SAST_DS_extra_2', 'N RUNS S17_OTHER_DEFAULT_SPLIT',
#        'N RUNS S17_RSAST_R10', 'N RUNS S17_OTHER_R10', 'ID', 'Name', 'Type',
#        'Train ', 'Test ', 'Class', 'Length', 'RSAST (10,10) WORST SAST?',
#        'O(|c|nm²)', 'O(|c|nm³)', 'Approx Time (hours)', 'L25', 'L50', 'L75',
#        'ED (w=0)', 'DTW (learned_w) ', 'DTW (w=100)', 'Default rate',
#        'Data donor/editor', '50/L', 'Unnamed: 30'],
#       dtype='object')

# %%
acc_per_type=pd.pivot_table(concatenated_df, values="accuracy", index=["dataset_name","Type",'classifier_name'])
#acc_per_type=concatenated_df
acc_per_type=acc_per_type.reset_index()

# %%
max_bx=max(acc_per_type.accuracy)
min_bx=min(acc_per_type.accuracy)


#df_to_cd=pd.pivot_table(df_to_cd, index=['dataset_name','classifier_name'], columns=['rpoint'],values='accuracy')
#df_to_cd = df_to_cd.reindex(columns=["1","10","30","50","100","half_len"])

#print(df_to_cd.head(5))

# Plot
fig, ax = plt.subplots()


#order=list(df_to_cd)
sns.boxplot(data=acc_per_type, y='Type', x='accuracy', hue ='classifier_name')
#plt.boxplot(df_to_cd, labels=list(df_to_cd), showfliers=False)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Axis details

ax.set(ylabel='dataset name', xlabel='accuracy', title='Accuracy Boxplot for Dataset:'+str(df_result["classifier_name"].unique()[0]))

#plt.xticks([1, 2, 3, 4, 5, 6],list(df_to_cd) )
#print(df_to_cd.describe())
plt.tight_layout()
# save plot
plt.savefig('ExperimentationRSAST/images_boxplot_acc_per_type/boxplot_acc_per_type.png')
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial

# %%
pd.pivot_table(acc_per_type,index='Type', aggfunc=lambda x: len(x.unique()))
# Out:
#            accuracy  classifier_name  dataset_name
# Type
# Device           30                5             6
# ECG              30                5             6
# Image           144                5            29
# Motion           69                5            14
# Sensor           83                5            18
# Simulated        23                5             5
# Spectro          32                5             7
